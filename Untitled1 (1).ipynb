# %%
# !pip install varname
! pip install kaggle
# %reload_ext tensorboard
# Out:
# Requirement already satisfied: varname in /home/redcoder/anaconda3/lib/python3.7/site-packages (0.8.3)
# Requirement already satisfied: executing<0.9.0,>=0.8.3 in /home/redcoder/anaconda3/lib/python3.7/site-packages (from varname) (0.8.3)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /home/redcoder/anaconda3/lib/python3.7/site-packages (from varname) (2.0.5)
# Requirement already satisfied: pure_eval<1.0.0 in /home/redcoder/anaconda3/lib/python3.7/site-packages (from varname) (0.2.2)
# Requirement already satisfied: six in /home/redcoder/anaconda3/lib/python3.7/site-packages (from asttokens<3.0.0,>=2.0.0->varname) (1.16.0)
# Requirement already satisfied: kaggle in /home/redcoder/anaconda3/lib/python3.7/site-packages (1.5.12)
# Requirement already satisfied: urllib3 in /home/redcoder/anaconda3/lib/python3.7/site-packages (from kaggle) (1.26.9)
# Requirement already satisfied: python-slugify in /home/redcoder/anaconda3/lib/python3.7/site-packages (from kaggle) (6.1.2)
# Requirement already satisfied: requests in /home/redcoder/anaconda3/lib/python3.7/site-packages (from kaggle) (2.27.1)
# Requirement already satisfied: tqdm in /home/redcoder/anaconda3/lib/python3.7/site-packages (from kaggle) (4.42.1)
# Requirement already satisfied: six>=1.10 in /home/redcoder/anaconda3/lib/python3.7/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /home/redcoder/anaconda3/lib/python3.7/site-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: python-dateutil in /home/redcoder/anaconda3/lib/python3.7/site-packages (from kaggle) (2.8.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/redcoder/anaconda3/lib/python3.7/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /home/redcoder/anaconda3/lib/python3.7/site-packages (from requests->kaggle) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /home/redcoder/anaconda3/lib/python3.7/site-packages (from requests->kaggle) (3.3)

# %%
from datetime import datetime as dt
# from varname import argname
import os

# from google.colab import drive
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
import zipfile

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/home/redcoder/.kaggle’: File exists

# %%
# !cp kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d ayushv322/animal-classification
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/redcoder/.kaggle/kaggle.json'
# animal-classification.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# # Extract dataset from zip to current session
# zip_ref = zipfile.ZipFile('animal-classification.zip', 'r') # Opens the zip file in read mode
# zip_ref.extractall('/content')
# zip_ref.close()

# %%
PATH = 'animal-classification/Data'
BATCH_SIZE = 32
IMG_SIZE = (160, 160)

# Split into train/test
# by default, class names are infered, and converted to int
train_dataset = tf.keras.utils.image_dataset_from_directory(directory = PATH,
                                                            validation_split=0.3,
                                                            subset='training',
                                                            shuffle=True,
                                                            seed=1,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE)

validation_dataset = tf.keras.utils.image_dataset_from_directory(directory = PATH,
                                                                 validation_split=0.3,
                                                                 subset='validation',
                                                                 shuffle=True,
                                                                 seed=1,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE)
# Out:
# Found 13273 files belonging to 5 classes.
# Using 9292 files for training.
# Found 13273 files belonging to 5 classes.
# Using 3981 files for validation.

# %%
# Create test dataset from validation dataset
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches // 5)
validation_dataset = validation_dataset.skip(val_batches // 5)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 100
# Number of test batches: 25

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
class_names
# Out:
# ['gallina', 'gatto', 'mucca', 'pecora', 'ragno']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
# Create a data augmentation model
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1): # Take 1 batch out
  plt.figure(figsize=(10, 10)) 
  first_image = image[0] # Take 1 image out from the batch
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255) # Rescale pixel value
    plt.axis('off')

# %%
# preprocess input using the function from the pre-trained model
preprocess_input = tf.keras.applications.vgg16.preprocess_input

# %%
# create base model from the pre-trained model
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.vgg16.VGG16(input_shape=IMG_SHAPE,
                                               include_top=False, 
                                               weights = 'imagenet')

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 160, 160, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 160, 160, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 80, 80, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 80, 80, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 80, 80, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 40, 40, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 40, 40, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 40, 40, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 40, 40, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 20, 20, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 20, 20, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 20, 20, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 20, 20, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 10, 10, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(base_model)

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
# batchsize, width, height, layer
print(feature_batch.shape)
# Out:
# (32, 5, 5, 512)

# %%
# freeze the base model
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 160, 160, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 160, 160, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 80, 80, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 80, 80, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 80, 80, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 40, 40, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 40, 40, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 40, 40, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 40, 40, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 20, 20, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 20, 20, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 20, 20, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 20, 20, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 10, 10, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# GlobalAveragePooling2D aggregate width and height into 1 dimension
# transforming the previous (32, 5, 5, 512) into (32, 512)
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 512)

# %%
len(class_names)
# Out:
# 5

# %%
# Use the output as it is, no activation function
prediction_layer = tf.keras.layers.Dense(len(class_names), activation='softmax')
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 5)

# %%
# use functional API to create the entire model, including the input pipeline and model
inputs = tf.keras.Input(shape=IMG_SHAPE) # shape can follow image shape
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential_2 (Sequential)   (None, 160, 160, 3)       0
#
#  tf.__operators__.getitem_2   (None, 160, 160, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_2 (TFOpLambd  (None, 160, 160, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 5, 5, 512)         14714688
#
#  global_average_pooling2d_2   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 14,717,253
# Trainable params: 2,565
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# compile
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# Get model performance before training
initial_epochs = 10

loss0, accuracy0 = model.evaluate(validation_dataset)
print('loss:', loss0)
print('accuracy:', accuracy0)
# Out:
# 100/100 [==============================] - 143s 1s/step - loss: 14.8289 - accuracy: 0.1638
# loss: 14.82894515991211
# accuracy: 0.1637849658727646

# %%
# train the last dense layer we added

logdir = os.path.join("logs", 'model')
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset,
                    callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 88/88 [==============================] - 153s 2s/step - loss: 11.2554 - accuracy: 0.0385 - val_loss: 9.7725 - val_accuracy: 0.0461
# Epoch 2/10
# 88/88 [==============================] - 162s 2s/step - loss: 9.2876 - accuracy: 0.0567 - val_loss: 8.4237 - val_accuracy: 0.0625
# Epoch 3/10
# 83/88 [===========================>..] - ETA: 6s - loss: 8.3636 - accuracy: 0.0651

# %%
loss, accuracy = model.evaluate(test_dataset)
print('Test accuracy :', accuracy)
# Out:
# 7/7 [==============================] - 19s 2s/step - loss: 3.9510 - accuracy: 0.4509
# Test accuracy : 0.4508928656578064

# %%
# Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch) # predict on 1 batch
pred_label = np.argmax(predictions, axis=1) # get the class index with max predictions

# compare prediction and labels
print('Predictions:\n', pred_label)
print('Labels:\n', label_batch)

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(image_batch[i].astype("uint8"))
  plt.title(class_names[pred_label[i]])
  plt.axis("off")
# Out:
# Predictions:
#  [0 3 3 2 1 1 3 3 2 2 2 1 3 3 2 3 2 3 3 3 2 1 3 2 1 2 3 3 1 2 2 2]
# Labels:
#  [3 3 3 3 0 2 3 3 1 2 1 1 3 3 2 3 0 3 3 3 2 1 3 0 2 1 3 3 0 1 1 1]

# %%
plt.imshow(image_batch[0].astype("uint8"))
predictions[0]
# Out:
# array([5.0841653e-01, 2.3815755e-05, 4.9055731e-01, 1.0023586e-03],
#       dtype=float32)
